# %% [markdown]
# # Import and Initialization

# %%
# Create a refactored file monitoring system for the Ki2 Alerts Python Package
# that accounts for the YYYY/MM directory structure with Data, Data_Burst, and Data_Burst_Symbols subfolders

import os
from pathlib import Path
import datetime
from typing import Dict, List, Tuple, Optional
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
import polars as pl
import logging
import time
import re
import pickle

from watchdog.observers import Observer

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %% [markdown]
# Operation of the monitoring system is based on the HFTA Burst Monitor Application being placed in the YYYY/MM Folder under the in the Data/Burst_Data Folder under the Project Root Directory.  This causes the Busrts Datat to be loaded into each of appropriate subfolders.  At the end of each month, the Burst Monitor program and it two support files (HFTAIP.txt and HFTUser.txt) are moved to the new monthly folder so that new daily data captures will go into the appropriate subfolders.  Using this approach segments the raw captured data by month making it available to packages such as DuckDB and packages that expect a Partitioned Parquet Data Lake or Partition Table like structure.
# To initiate daily monitoring the Burst Monitor executable must be turend on and the "Connect" Button push to connect to the remote server.  There is no automated way to do this at this time although PlayWrite or other browser automation tools migh be implemented in the Future.
# As part of this project an n8n method needs to be developed to execute the startup of the executable file aon a time basis.  In order to catach early morning "Flyer" activity intiated by social media promotersm the current thinking is that this should take place at 6 AM New York time.
# When the monitor is operational the Ki2AlertsFileMonitor Object must be created. The code for this is as follows:
#
#     ```# Initialize the monitor - Set base_path to project root + "Data/Burst_Data"
#
#     project_root = Path.cwd().parent
#     print(f"Project root: {project_root}")
#     base_path = project_root / "Data" / "Burst_Data"
#     base_path.mkdir(parents=True, exist_ok=True)
#     monitor = Ki2AlertsFileMonitor(str(base_path))```
#
# Next the get_current_year_month_path method is executed to make sure the directory is created and available
#
#     ```# Directory creation
#     current_path = monitor.get_current_year_month_path()```
#
# This verifies that the directories for the current yyyy/mm for the current data are created and availble.  A list of Monitored directories can then be generated
#
# ```    # List monitored directories
#     directories = monitor.list_all_monitored_directories()```
#
# This code will check the monitored directories and retrun only the files associated with the target date.  This date must be within the YYYY/MM that was previously selected.  This will alos print the files that are found and make three separate file list parsed_files_data, parsed_files_burst, and parsed_files_burst_symbols
#
# ```target_date = date.today()
#     # or target_date = target_date = date(2025, 8, 29)
#
#     # Iterate through all subfolder types and scan for files in each, select only files from target date
#     # target_date = date(2025, 8, 28)
#     target_date = date.today()
#     subfolder_types = ['data', 'data_burst', 'data_burst_symbols']
#
#     parsed_files_data = [monitor.parse_filename(f, subfolder_types[0]) for f in parsed_files_data]
#     parsed_files_data = [info for info in parsed_files_data if info]
#     for info in parsed_files_data:
#         print(info)
#
#     parsed_files_burst = monitor.scan_for_files(subfolder_types[1], target_date, filter_by_date=True)
#     parsed_files_burst = [monitor.parse_filename(f, subfolder_types[1]) for f in parsed_files_burst]
#     parsed_files_burst = [info for info in parsed_files_burst if info]
#     for info in parsed_files_burst:
#         print(info)
#
#     parsed_files_burst_symbols = monitor.scan_for_files(subfolder_types[2], target_date, filter_by_date=True)
#     parsed_files_burst_symbols = [monitor.parse_filename(f, subfolder_types[2]) for f in parsed_files_burst_symbols]
#     parsed_files_burst_symbols = [info for info in parsed_files_burst_symbols if info]
#
#     for info in parsed_files_burst_symbols:
#         print(info) ```
#
#     Once this setup is done there will be three dictionaries with files that need to be process for a specifc target day and each dictionary will have full file path and date in both datetime and date_string form

# %% [markdown]
# # Date File Monitoring Class

# %%
class Ki2AlertsFileMonitor:
    """
    File monitoring system that handles the YYYY/MM directory structure
    with Data, Data_Burst, and Data_Burst_Symbols subfolders.
    """
    
    def __init__(self, base_path: str):
        self.base_path = Path(base_path)
        self.observers = {}
        self.file_handlers = {}
        
        # Define the expected subfolder structure
        self.subfolders = {
            'data': 'Data',
            'data_burst': 'Data_Burst', 
            'data_burst_symbols': 'Data_Burst_Symbols',
            'processed_data': 'Processed_Data'
        }
        
        # File patterns for different folder types
        self.file_patterns = {
            'data': r'^(\d{8})_hft([123])\.csv$',  # YYYYMMDDhft1.csv, etc.
            'data_burst': r'^(\d{8})\.csv$',       # YYYYMMDD.csv
            'data_burst_symbols': r'^Burst_(\d{8})_(\d{6})\.csv$'  # BurstYYYYMMDDhhmmss.csv
        }
        
        self._validate_base_path()
    
    def _validate_base_path(self):
        """Validate that the base path exists and create if necessary."""
        if not self.base_path.exists():
            self.base_path.mkdir(parents=True, exist_ok=True)
            logger.info(f"Created base directory: {self.base_path}")
    
    def get_year_month_directories(self) -> List[Tuple[str, str, Path]]:
        """
        Scan the base path for existing YYYY/MM directory structures.
        Returns: List of (year, month, path) tuples
        """
        directories = []
        
        for year_dir in self.base_path.iterdir():
            if year_dir.is_dir() and re.match(r'^\d{4}$', year_dir.name):
                year = year_dir.name
                
                for month_dir in year_dir.iterdir():
                    if month_dir.is_dir() and re.match(r'^\d{2}$', month_dir.name):
                        month = month_dir.name
                        directories.append((year, month, month_dir))
        
        return sorted(directories)
    
    def create_directory_structure(self, year: str, month: str) -> Path:
        """
        Create the complete directory structure for a given year/month. If one exists, it will be verified.

        Structure:
        base_path/
        └── YYYY/
            └── MM/
                ├── Data/
                ├── Data_Burst/
                ├── Data_Burst_Symbols/
                └── ProcessedData/
        """
        year_month_path = self.base_path / year / month
        created = False
        for subfolder in self.subfolders.values():
            subfolder_path = year_month_path / subfolder
            if not subfolder_path.exists():
                subfolder_path.mkdir(parents=True, exist_ok=True)
                created = True
        if created:
            logger.info(f"Created directory structure for {year}/{month}")
        else:
            logger.info(f"Verified directory structure for {year}/{month}")
        return year_month_path
    
    def get_current_year_month_path(self) -> Path:
        """Get or create the directory path for the current year/month."""
        current_date = datetime.date.today()
        year = str(current_date.year)
        month = f"{current_date.month:02d}"
        
        return self.create_directory_structure(year, month)
    
    def get_paths_for_date(self, target_date: datetime.date) -> Dict[str, Path]:
        """
        Get all subfolder paths for a specific date.
        
        Args:
            target_date: The date for which to get paths
            
        Returns:
            Dictionary with subfolder names as keys and Path objects as values
        """
        
        year = str(target_date.year)
        month = f"{target_date.month:02d}"
        
        base_path = self.create_directory_structure(year, month)
        
        paths = {}
        for key, subfolder in self.subfolders.items():
            paths[key] = base_path / subfolder
        
        return paths

    def scan_for_files(self, subfolder_type: str, target_date: 'Optional[datetime.date]' = None, filter_by_date: bool = True) -> List[Path]:
        """
        Scan a specific subfolder type for files matching the expected pattern.

        Args:
            subfolder_type: One of 'data', 'data_burst', 'data_burst_symbols'
            target_date: Specific date to scan. If None, returns all files in the folder.
            filter_by_date: If True, only return files matching the target_date. If False, return all files.

        Returns:
            List of Path objects for matching files
        """
    
        if target_date is None:
            # If no date, scan all year/month folders for all files
            matching_files = []
            for year, month, month_dir in self.get_year_month_directories():
                folder_path = month_dir / self.subfolders[subfolder_type]
                if not folder_path.exists():
                    continue
                pattern = self.file_patterns[subfolder_type]
                for file_path in folder_path.iterdir():
                    if file_path.is_file() and re.match(pattern, file_path.name):
                        matching_files.append(file_path)
            return sorted(matching_files)
        
        # If date is given, scan only that year/month folder
        print(f"Scanning {subfolder_type} for date {target_date}")
        paths = self.get_paths_for_date(target_date)
        folder_path = paths[subfolder_type]
        if not folder_path.exists():
            return []
        pattern = self.file_patterns[subfolder_type]
        matching_files = []
        for file_path in folder_path.iterdir():
            if file_path.is_file() and re.match(pattern, file_path.name):
                if filter_by_date:
                    parsed = self.parse_filename(file_path, subfolder_type)
                    if parsed.get('date') == target_date:
                        matching_files.append(file_path)
                else:
                    matching_files.append(file_path)
        return sorted(matching_files)
    
    def parse_filename(self, file_path: Path, subfolder_type: str) -> Dict:
        """
        Parse filename to extract date and other information.
        
        Args:
            file_path: Path to the file
            subfolder_type: Type of subfolder ('data', 'data_burst', 'data_burst_symbols')
            
        Returns:
            Dictionary with parsed information
        """
        filename = file_path.name
        pattern = self.file_patterns[subfolder_type]
        match = re.match(pattern, filename)
        
        if not match:
            return {}
        
        result = {
            'filename': filename,
            'full_path': str(file_path),
            'subfolder_type': subfolder_type
        }
        
        if subfolder_type == 'data':
            date_str, file_num = match.groups()
            result.update({
                'date': datetime.datetime.strptime(date_str, '%Y%m%d').date(),
                'file_number': int(file_num),
                'date_string': date_str
            })
        elif subfolder_type == 'data_burst':
            date_str = match.group(1)
            result.update({
                'date': datetime.datetime.strptime(date_str, '%Y%m%d').date(),
                'date_string': date_str
            })
        elif subfolder_type == 'data_burst_symbols':
            date_str, time_str = match.groups()
            datetime_str = date_str + time_str
            result.update({
                'datetime': datetime.datetime.strptime(datetime_str, '%Y%m%d%H%M%S'),
                'date': datetime.datetime.strptime(date_str, '%Y%m%d').date(),
                'date_string': date_str,
                'time_string': time_str
            })
        
        return result
    
    def get_processed_data_path(self, target_date: 'Optional[datetime.date]' = None) -> Path:
        """Get the ProcessedData path for a specific date."""
        if target_date is None:
            target_date = datetime.date.today()

        paths = self.get_paths_for_date(target_date)
        return paths['processed_data']
    
    def list_all_monitored_directories(self) -> List[Dict]:
        """
        List all existing YYYY/MM directories that should be monitored.
        
        Returns:
            List of dictionaries with directory information
        """
        directories = []
        
        for year, month, path in self.get_year_month_directories():
            dir_info = {
                'year': year,
                'month': month,
                'path': str(path),
                'subfolders': {}
            }
            
            # Check which subfolders exist
            for key, subfolder in self.subfolders.items():
                subfolder_path = path / subfolder
                dir_info['subfolders'][key] = {
                    'exists': subfolder_path.exists(),
                    'path': str(subfolder_path)
                }
            
            directories.append(dir_info)
        
        return directories
    
    def get_last_position_path(self, file_path: Path) -> Path:
        """
        Get the path for the .pkl file that stores the last processed file pointer for a given file.
        """
        # Try to parse the date from the filename
        # You need to know the subfolder_type; here is a safe guess based on parent folder name
        parent_folder = file_path.parent.name.lower()
        if "burst_symbol" in parent_folder:
            subfolder_type = "data_burst_symbols"
        elif "burst" in parent_folder:
            subfolder_type = "data_burst"
        elif "data" in parent_folder:
            subfolder_type = "data"
        else:
            subfolder_type = "data"

        parsed = self.parse_filename(file_path, subfolder_type)
        target_date = parsed.get("date", None)

        processed_dir = self.get_processed_data_path(target_date)
        last_pos_filename = f"{file_path.stem}_lastpos.pkl"
        return processed_dir / last_pos_filename

    def load_last_position(self, file_path: Path) -> int:
        """
        Load the last processed file pointer position from a .pkl file.
        """
        last_pos_path = self.get_last_position_path(file_path)
        if last_pos_path.exists():
            with open(last_pos_path, "rb") as f:
                return pickle.load(f)
        return 0

    def save_last_position(self, file_path: Path, position: int):
        """
        Save the last processed file pointer position to a .pkl file.
        """
        last_pos_path = self.get_last_position_path(file_path)
        last_pos_path.parent.mkdir(parents=True, exist_ok=True)
        with open(last_pos_path, "wb") as f:
            pickle.dump(position, f)

# %% [markdown]
# # File Event Handling Class

# %%
# Create an event handler for file monitoring
class BurstFileEventHandler(FileSystemEventHandler):
    """Event handler for monitoring file changes in the burst monitoring system."""
    
    def __init__(self, monitor: Ki2AlertsFileMonitor, subfolder_type: str):
        self.monitor = monitor
        self.subfolder_type = subfolder_type
        super().__init__()
    
    def on_created(self, event):
        if not event.is_directory:
            self._handle_file_event(event.src_path, "created")
    
    def on_modified(self, event):
        if not event.is_directory:
            self._handle_file_event(event.src_path, "modified")
    
    def _handle_file_event(self, file_path: str, event_type: str):
        file_path = Path(file_path)
        parsed_info = self.monitor.parse_filename(file_path, self.subfolder_type)

        if parsed_info:
            logger.info(f"File {event_type}: {file_path.name} in {self.subfolder_type}")
            logger.info(f"Parsed info: {parsed_info}")
            # Only process new information since last pointer
            last_pos = self.monitor.load_last_position(file_path)
            logger.info(f"Last processed position: {last_pos}")
            try:
                with open(file_path, "r", encoding="utf-8") as f:
                    f.seek(last_pos)
                    new_lines = f.readlines()
                    if new_lines:
                        logger.info(f"Processing {len(new_lines)} new lines in {file_path.name}")
                        # Here you would process new_lines as needed
                        # For demonstration, just log the first line
                        logger.info(f"First new line: {new_lines[0].strip() if new_lines else 'None'}")
                        # Save new file pointer position
                        self.monitor.save_last_position(file_path, f.tell())
            except Exception as e:
                logger.error(f"Error processing file {file_path}: {e}")
            # Trigger appropriate processing based on subfolder type
            if self.subfolder_type == 'data_burst_symbols':
                self._process_burst_symbols_file(file_path, parsed_info)
            elif self.subfolder_type == 'data_burst':
                self._process_data_burst_file(file_path, parsed_info)
            elif self.subfolder_type == 'data':
                self._process_data_file(file_path, parsed_info)
    
    def _process_burst_symbols_file(self, file_path: Path, parsed_info: Dict):
        """Process BurstYYYYMMDDhhmmss.csv files."""
        logger.info(f"Processing burst symbols file: {file_path.name}")
        # This would trigger the main analysis pipeline
        
    def _process_data_burst_file(self, file_path: Path, parsed_info: Dict):
        """Process YYYYMMDD.csv files from Data_Burst folder."""
        logger.info(f"Processing data burst file: {file_path.name}")
        
    def _process_data_file(self, file_path: Path, parsed_info: Dict):
        """Process YYYYMMDDhft*.csv files from Data folder."""
        logger.info(f"Processing data file: {file_path.name}")

# %% [markdown]
# # Daily Usage Script

# %%
# Initialize the monitor - Set base_path to project root + "Data/Burst_Data"
project_root = Path.cwd().parent
print(f"Project root: {project_root}")
base_path = project_root / "Data" / "Burst_Data"
base_path.mkdir(parents=True, exist_ok=True)
monitor = Ki2AlertsFileMonitor(str(base_path))

# Directory creation / Verification
current_path = monitor.get_current_year_month_path()

# List monitored directories
directories = monitor.list_all_monitored_directories()

# Iterate through all subfolder types and scan for files in each, select only files from target date
target_date = datetime.date(2025, 8, 28)
# target_date = date.today()
subfolder_types = ['data', 'data_burst', 'data_burst_symbols']

parsed_files_data = monitor.scan_for_files(subfolder_types[0], target_date, filter_by_date=True)
parsed_files_data = [monitor.parse_filename(f, subfolder_types[0]) for f in parsed_files_data]
parsed_files_data = [info for info in parsed_files_data if info]
for info in parsed_files_data:
    print(info)

parsed_files_burst = monitor.scan_for_files(subfolder_types[1], target_date, filter_by_date=True)
parsed_files_burst = [monitor.parse_filename(f, subfolder_types[1]) for f in parsed_files_burst]
parsed_files_burst = [info for info in parsed_files_burst if info]
for info in parsed_files_burst:
    print(info)

parsed_files_burst_symbols = monitor.scan_for_files(subfolder_types[2], target_date, filter_by_date=True)
parsed_files_burst_symbols = [monitor.parse_filename(f, subfolder_types[2]) for f in parsed_files_burst_symbols]
parsed_files_burst_symbols = [info for info in parsed_files_burst_symbols if info]
for info in parsed_files_burst_symbols:
    print(info)

parsed_files_data
# Out:
# 2025-08-31 15:56:31,653 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:56:31,656 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:56:31,660 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:56:31,664 - INFO - Verified directory structure for 2025/08
# Project root: c:\Users\vande\Desktop\Projects\Ki2_Alerts
# Scanning data for date 2025-08-28
# {'filename': '20250828_hft1.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250828_hft1.csv', 'subfolder_type': 'data', 'date': datetime.date(2025, 8, 28), 'file_number': 1, 'date_string': '20250828'}
# {'filename': '20250828_hft2.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250828_hft2.csv', 'subfolder_type': 'data', 'date': datetime.date(2025, 8, 28), 'file_number': 2, 'date_string': '20250828'}
# {'filename': '20250828_hft3.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250828_hft3.csv', 'subfolder_type': 'data', 'date': datetime.date(2025, 8, 28), 'file_number': 3, 'date_string': '20250828'}
# Scanning data_burst for date 2025-08-28
# {'filename': '20250828.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250828.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 28), 'date_string': '20250828'}
# Scanning data_burst_symbols for date 2025-08-28
# {'filename': 'Burst_20250828_093001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 30, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093001'}
# {'filename': 'Burst_20250828_093011.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093011.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 30, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093011'}
# {'filename': 'Burst_20250828_093012.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093012.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 30, 12), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093012'}
# {'filename': 'Burst_20250828_093014.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093014.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 30, 14), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093014'}
# {'filename': 'Burst_20250828_093038.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093038.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 30, 38), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093038'}
# {'filename': 'Burst_20250828_093042.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093042.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 30, 42), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093042'}
# {'filename': 'Burst_20250828_093045.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093045.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 30, 45), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093045'}
# {'filename': 'Burst_20250828_093101.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093101.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093101'}
# {'filename': 'Burst_20250828_093102.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093102.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093102'}
# {'filename': 'Burst_20250828_093104.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093104.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 4), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093104'}
# {'filename': 'Burst_20250828_093109.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093109.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 9), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093109'}
# {'filename': 'Burst_20250828_093110.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093110.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 10), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093110'}
# {'filename': 'Burst_20250828_093111.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093111.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093111'}
# {'filename': 'Burst_20250828_093123.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093123.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 23), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093123'}
# {'filename': 'Burst_20250828_093126.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093126.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 31, 26), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093126'}
# {'filename': 'Burst_20250828_093508.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093508.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 8), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093508'}
# {'filename': 'Burst_20250828_093517.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093517.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 17), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093517'}
# {'filename': 'Burst_20250828_093520.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093520.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 20), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093520'}
# {'filename': 'Burst_20250828_093530.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093530.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 30), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093530'}
# {'filename': 'Burst_20250828_093538.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093538.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 38), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093538'}
# {'filename': 'Burst_20250828_093539.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093539.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 39), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093539'}
# {'filename': 'Burst_20250828_093548.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093548.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 48), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093548'}
# {'filename': 'Burst_20250828_093556.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093556.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 35, 56), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093556'}
# {'filename': 'Burst_20250828_093602.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093602.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093602'}
# {'filename': 'Burst_20250828_093604.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093604.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 4), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093604'}
# {'filename': 'Burst_20250828_093606.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093606.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 6), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093606'}
# {'filename': 'Burst_20250828_093610.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093610.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 10), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093610'}
# {'filename': 'Burst_20250828_093612.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093612.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 12), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093612'}
# {'filename': 'Burst_20250828_093615.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093615.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 15), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093615'}
# {'filename': 'Burst_20250828_093618.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093618.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 18), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093618'}
# {'filename': 'Burst_20250828_093619.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093619.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 19), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093619'}
# {'filename': 'Burst_20250828_093620.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093620.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 20), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093620'}
# {'filename': 'Burst_20250828_093622.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093622.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 22), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093622'}
# {'filename': 'Burst_20250828_093623.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093623.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 23), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093623'}
# {'filename': 'Burst_20250828_093633.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093633.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 36, 33), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093633'}
# {'filename': 'Burst_20250828_093701.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093701.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093701'}
# {'filename': 'Burst_20250828_093702.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093702.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093702'}
# {'filename': 'Burst_20250828_093711.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093711.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093711'}
# {'filename': 'Burst_20250828_093712.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093712.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 12), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093712'}
# {'filename': 'Burst_20250828_093717.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093717.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 17), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093717'}
# {'filename': 'Burst_20250828_093725.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093725.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 25), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093725'}
# {'filename': 'Burst_20250828_093732.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093732.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 32), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093732'}
# {'filename': 'Burst_20250828_093736.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093736.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 37, 36), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093736'}
# {'filename': 'Burst_20250828_093801.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093801.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 38, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093801'}
# {'filename': 'Burst_20250828_093806.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093806.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 38, 6), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093806'}
# {'filename': 'Burst_20250828_093815.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_093815.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 38, 15), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '093815'}
# {'filename': 'Burst_20250828_094001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 40, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094001'}
# {'filename': 'Burst_20250828_094026.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094026.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 40, 26), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094026'}
# {'filename': 'Burst_20250828_094039.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094039.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 40, 39), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094039'}
# {'filename': 'Burst_20250828_094101.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094101.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 41, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094101'}
# {'filename': 'Burst_20250828_094104.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094104.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 41, 4), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094104'}
# {'filename': 'Burst_20250828_094211.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094211.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 42, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094211'}
# {'filename': 'Burst_20250828_094219.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094219.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 42, 19), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094219'}
# {'filename': 'Burst_20250828_094317.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094317.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 43, 17), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094317'}
# {'filename': 'Burst_20250828_094424.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094424.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 44, 24), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094424'}
# {'filename': 'Burst_20250828_094501.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094501.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094501'}
# {'filename': 'Burst_20250828_094502.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094502.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094502'}
# {'filename': 'Burst_20250828_094515.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094515.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 15), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094515'}
# {'filename': 'Burst_20250828_094528.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094528.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 28), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094528'}
# {'filename': 'Burst_20250828_094533.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094533.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 33), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094533'}
# {'filename': 'Burst_20250828_094544.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094544.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 44), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094544'}
# {'filename': 'Burst_20250828_094545.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094545.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 45), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094545'}
# {'filename': 'Burst_20250828_094549.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094549.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 49), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094549'}
# {'filename': 'Burst_20250828_094557.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094557.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 45, 57), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094557'}
# {'filename': 'Burst_20250828_094601.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094601.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094601'}
# {'filename': 'Burst_20250828_094606.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094606.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 6), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094606'}
# {'filename': 'Burst_20250828_094607.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094607.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 7), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094607'}
# {'filename': 'Burst_20250828_094608.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094608.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 8), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094608'}
# {'filename': 'Burst_20250828_094611.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094611.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094611'}
# {'filename': 'Burst_20250828_094612.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094612.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 12), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094612'}
# {'filename': 'Burst_20250828_094613.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094613.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 13), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094613'}
# {'filename': 'Burst_20250828_094627.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094627.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 27), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094627'}
# {'filename': 'Burst_20250828_094630.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094630.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 30), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094630'}
# {'filename': 'Burst_20250828_094639.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094639.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 39), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094639'}
# {'filename': 'Burst_20250828_094643.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094643.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 43), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094643'}
# {'filename': 'Burst_20250828_094646.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094646.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 46, 46), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094646'}
# {'filename': 'Burst_20250828_094718.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094718.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 47, 18), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094718'}
# {'filename': 'Burst_20250828_094733.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094733.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 47, 33), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094733'}
# {'filename': 'Burst_20250828_094803.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094803.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 48, 3), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094803'}
# {'filename': 'Burst_20250828_094823.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094823.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 48, 23), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094823'}
# {'filename': 'Burst_20250828_094824.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094824.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 48, 24), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094824'}
# {'filename': 'Burst_20250828_094831.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094831.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 48, 31), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094831'}
# {'filename': 'Burst_20250828_094851.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094851.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 48, 51), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094851'}
# {'filename': 'Burst_20250828_094947.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_094947.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 49, 47), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '094947'}
# {'filename': 'Burst_20250828_095001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095001'}
# {'filename': 'Burst_20250828_095002.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095002.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095002'}
# {'filename': 'Burst_20250828_095003.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095003.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 3), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095003'}
# {'filename': 'Burst_20250828_095013.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095013.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 13), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095013'}
# {'filename': 'Burst_20250828_095014.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095014.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 14), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095014'}
# {'filename': 'Burst_20250828_095016.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095016.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 16), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095016'}
# {'filename': 'Burst_20250828_095019.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095019.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 19), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095019'}
# {'filename': 'Burst_20250828_095020.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095020.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 20), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095020'}
# {'filename': 'Burst_20250828_095023.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095023.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 23), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095023'}
# {'filename': 'Burst_20250828_095025.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095025.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 25), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095025'}
# {'filename': 'Burst_20250828_095026.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095026.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 26), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095026'}
# {'filename': 'Burst_20250828_095027.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095027.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 27), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095027'}
# {'filename': 'Burst_20250828_095030.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095030.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 30), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095030'}
# {'filename': 'Burst_20250828_095031.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095031.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 31), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095031'}
# {'filename': 'Burst_20250828_095032.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095032.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 32), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095032'}
# {'filename': 'Burst_20250828_095035.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095035.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 35), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095035'}
# {'filename': 'Burst_20250828_095037.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095037.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 37), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095037'}
# {'filename': 'Burst_20250828_095038.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095038.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 38), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095038'}
# {'filename': 'Burst_20250828_095039.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095039.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 39), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095039'}
# {'filename': 'Burst_20250828_095040.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095040.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 40), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095040'}
# {'filename': 'Burst_20250828_095041.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095041.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 41), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095041'}
# {'filename': 'Burst_20250828_095042.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095042.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 42), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095042'}
# {'filename': 'Burst_20250828_095043.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095043.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 43), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095043'}
# {'filename': 'Burst_20250828_095044.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095044.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 44), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095044'}
# {'filename': 'Burst_20250828_095045.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095045.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 45), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095045'}
# {'filename': 'Burst_20250828_095046.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095046.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 46), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095046'}
# {'filename': 'Burst_20250828_095047.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095047.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 47), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095047'}
# {'filename': 'Burst_20250828_095048.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095048.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 48), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095048'}
# {'filename': 'Burst_20250828_095049.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095049.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 50, 49), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095049'}
# {'filename': 'Burst_20250828_095101.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095101.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095101'}
# {'filename': 'Burst_20250828_095102.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095102.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095102'}
# {'filename': 'Burst_20250828_095104.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095104.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 4), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095104'}
# {'filename': 'Burst_20250828_095108.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095108.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 8), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095108'}
# {'filename': 'Burst_20250828_095110.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095110.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 10), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095110'}
# {'filename': 'Burst_20250828_095118.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095118.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 18), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095118'}
# {'filename': 'Burst_20250828_095120.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095120.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 20), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095120'}
# {'filename': 'Burst_20250828_095139.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095139.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 39), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095139'}
# {'filename': 'Burst_20250828_095144.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095144.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 44), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095144'}
# {'filename': 'Burst_20250828_095146.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095146.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 46), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095146'}
# {'filename': 'Burst_20250828_095151.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095151.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 51), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095151'}
# {'filename': 'Burst_20250828_095154.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095154.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 54), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095154'}
# {'filename': 'Burst_20250828_095157.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095157.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 51, 57), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095157'}
# {'filename': 'Burst_20250828_095202.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_095202.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 9, 52, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '095202'}
# ...
# {'filename': 'Burst_20250828_103837.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_103837.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 10, 38, 37), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '103837'}
# {'filename': 'Burst_20250828_104032.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_104032.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 10, 40, 32), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '104032'}
# {'filename': 'Burst_20250828_104945.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_104945.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 10, 49, 45), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '104945'}
# {'filename': 'Burst_20250828_104947.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_104947.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 10, 49, 47), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '104947'}
# {'filename': 'Burst_20250828_111637.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_111637.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 16, 37), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '111637'}
# {'filename': 'Burst_20250828_111639.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_111639.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 16, 39), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '111639'}
# {'filename': 'Burst_20250828_111934.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_111934.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 19, 34), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '111934'}
# {'filename': 'Burst_20250828_112028.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112028.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 20, 28), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112028'}
# {'filename': 'Burst_20250828_112201.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112201.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 22, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112201'}
# {'filename': 'Burst_20250828_112519.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112519.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 25, 19), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112519'}
# {'filename': 'Burst_20250828_112534.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112534.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 25, 34), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112534'}
# {'filename': 'Burst_20250828_112629.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112629.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 26, 29), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112629'}
# {'filename': 'Burst_20250828_112630.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112630.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 26, 30), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112630'}
# {'filename': 'Burst_20250828_112901.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112901.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 29, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112901'}
# {'filename': 'Burst_20250828_112902.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_112902.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 29, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '112902'}
# {'filename': 'Burst_20250828_114502.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_114502.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 45, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '114502'}
# {'filename': 'Burst_20250828_115729.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_115729.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 11, 57, 29), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '115729'}
# {'filename': 'Burst_20250828_122811.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_122811.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 12, 28, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '122811'}
# {'filename': 'Burst_20250828_122812.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_122812.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 12, 28, 12), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '122812'}
# {'filename': 'Burst_20250828_122813.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_122813.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 12, 28, 13), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '122813'}
# {'filename': 'Burst_20250828_124815.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_124815.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 12, 48, 15), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '124815'}
# {'filename': 'Burst_20250828_150514.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_150514.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 5, 14), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '150514'}
# {'filename': 'Burst_20250828_155001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 50, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155001'}
# {'filename': 'Burst_20250828_155002.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155002.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 50, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155002'}
# {'filename': 'Burst_20250828_155022.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155022.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 50, 22), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155022'}
# {'filename': 'Burst_20250828_155101.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155101.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 51, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155101'}
# {'filename': 'Burst_20250828_155102.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155102.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 51, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155102'}
# {'filename': 'Burst_20250828_155211.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155211.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 52, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155211'}
# {'filename': 'Burst_20250828_155411.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155411.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 54, 11), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155411'}
# {'filename': 'Burst_20250828_155441.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155441.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 54, 41), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155441'}
# {'filename': 'Burst_20250828_155451.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155451.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 54, 51), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155451'}
# {'filename': 'Burst_20250828_155501.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155501.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 55, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155501'}
# {'filename': 'Burst_20250828_155502.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155502.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 55, 2), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155502'}
# {'filename': 'Burst_20250828_155503.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155503.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 55, 3), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155503'}
# {'filename': 'Burst_20250828_155504.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155504.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 55, 4), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155504'}
# {'filename': 'Burst_20250828_155801.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155801.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 58, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155801'}
# {'filename': 'Burst_20250828_155901.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155901.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 59, 1), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155901'}
# {'filename': 'Burst_20250828_155956.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155956.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 59, 56), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155956'}
# {'filename': 'Burst_20250828_155958.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155958.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 59, 58), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155958'}
# {'filename': 'Burst_20250828_155959.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_155959.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 15, 59, 59), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '155959'}
# {'filename': 'Burst_20250828_160000.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250828_160000.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 28, 16, 0), 'date': datetime.date(2025, 8, 28), 'date_string': '20250828', 'time_string': '160000'}
# [{'filename': '20250828_hft1.csv',
#   'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250828_hft1.csv',
#   'subfolder_type': 'data',
#   'date': datetime.date(2025, 8, 28),
#   'file_number': 1,
#   'date_string': '20250828'},
#  {'filename': '20250828_hft2.csv',
#   'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250828_hft2.csv',
#   'subfolder_type': 'data',
#   'date': datetime.date(2025, 8, 28),
#   'file_number': 2,
#   'date_string': '20250828'},
#  {'filename': '20250828_hft3.csv',
#   'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250828_hft3.csv',
#   'subfolder_type': 'data',
#   'date': datetime.date(2025, 8, 28),
#   'file_number': 3,
#   'date_string': '20250828'}]

# %%
from watchdog.observers import Observer

# Assume monitor is your Ki2AlertsFileMonitor instance
observer = Observer()

# For each subfolder type you want to monitor
for subfolder_type in ['data', 'data_burst', 'data_burst_symbols']:
    # Get the directory path for the current date (or any date you want)
    paths = monitor.get_paths_for_date(target_date)
    print(f"Monitoring paths: {paths}")
    folder_path = paths[subfolder_type]
    print(f"Monitoring folder_path: {folder_path}")
    # Create and schedule the event handler
    event_handler = BurstFileEventHandler(monitor, subfolder_type)
    observer.schedule(event_handler, str(folder_path), recursive=False)

# Start monitoring (this runs in the background)
observer.start()

# Keep the script running (or use try/finally to stop observer on exit)
try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    observer.stop()
observer.join()
# Out:
# 2025-08-31 15:56:42,954 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:56:42,957 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:56:42,958 - INFO - Verified directory structure for 2025/08
# Monitoring paths: {'data': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data'), 'data_burst': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data_Burst'), 'data_burst_symbols': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data_Burst_Symbols'), 'processed_data': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Processed_Data')}
# Monitoring folder_path: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08\Data
# Monitoring paths: {'data': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data'), 'data_burst': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data_Burst'), 'data_burst_symbols': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data_Burst_Symbols'), 'processed_data': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Processed_Data')}
# Monitoring folder_path: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08\Data_Burst
# Monitoring paths: {'data': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data'), 'data_burst': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data_Burst'), 'data_burst_symbols': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Data_Burst_Symbols'), 'processed_data': WindowsPath('c:/Users/vande/Desktop/Projects/Ki2_Alerts/Data/Burst_Data/2025/08/Processed_Data')}
# Monitoring folder_path: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08\Data_Burst_Symbols
# 2025-08-31 15:56:58,971 - INFO - File modified: 20250827.csv in data_burst
# 2025-08-31 15:56:58,975 - INFO - Parsed info: {'filename': '20250827.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250827.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 27), 'date_string': '20250827'}
# 2025-08-31 15:56:58,977 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:56:58,979 - INFO - Last processed position: 0
# 2025-08-31 15:56:58,979 - INFO - Processing 93 new lines in 20250827.csv
# 2025-08-31 15:56:58,981 - INFO - First new line: 093001,3,0,0,87,288,1,0,0
# 2025-08-31 15:56:58,986 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:56:58,988 - INFO - Processing data burst file: 20250827.csv
# 2025-08-31 15:57:04,150 - INFO - File modified: 20250827.csv in data_burst
# 2025-08-31 15:57:04,155 - INFO - Parsed info: {'filename': '20250827.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250827.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 27), 'date_string': '20250827'}
# 2025-08-31 15:57:04,158 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:57:04,174 - INFO - Last processed position: 2784
# 2025-08-31 15:57:04,178 - INFO - Processing data burst file: 20250827.csv
# 2025-08-31 15:57:04,182 - INFO - File modified: 20250827.csv in data_burst
# 2025-08-31 15:57:04,183 - INFO - Parsed info: {'filename': '20250827.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250827.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 27), 'date_string': '20250827'}
# 2025-08-31 15:57:04,187 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:57:04,190 - INFO - Last processed position: 2784
# 2025-08-31 15:57:04,192 - INFO - Processing data burst file: 20250827.csv
# 2025-08-31 15:57:50,135 - INFO - File modified: 20250828.csv in data_burst
# 2025-08-31 15:57:50,141 - INFO - Parsed info: {'filename': '20250828.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250828.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 28), 'date_string': '20250828'}
# 2025-08-31 15:57:50,143 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:57:50,145 - INFO - Last processed position: 0
# 2025-08-31 15:57:50,146 - INFO - Processing 242 new lines in 20250828.csv
# 2025-08-31 15:57:50,150 - INFO - First new line: 093001,3,0,0,112,324,1,0,0
# 2025-08-31 15:57:50,157 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:57:50,162 - INFO - Processing data burst file: 20250828.csv
# 2025-08-31 15:59:36,141 - INFO - File modified: 20250828.csv in data_burst
# 2025-08-31 15:59:36,141 - INFO - Parsed info: {'filename': '20250828.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250828.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 28), 'date_string': '20250828'}
# 2025-08-31 15:59:36,146 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:59:36,178 - INFO - Last processed position: 7538
# 2025-08-31 15:59:36,181 - INFO - Processing data burst file: 20250828.csv
# 2025-08-31 15:59:36,183 - INFO - File modified: 20250828.csv in data_burst
# 2025-08-31 15:59:36,184 - INFO - Parsed info: {'filename': '20250828.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250828.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 28), 'date_string': '20250828'}
# 2025-08-31 15:59:36,185 - INFO - Verified directory structure for 2025/08
# 2025-08-31 15:59:36,187 - INFO - Last processed position: 7538
# 2025-08-31 15:59:36,190 - INFO - Processing data burst file: 20250828.csv
# 2025-08-31 16:00:37,555 - INFO - File modified: 20250828.csv in data_burst
# 2025-08-31 16:00:37,556 - INFO - Parsed info: {'filename': '20250828.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250828.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 28), 'date_string': '20250828'}
# 2025-08-31 16:00:37,561 - INFO - Verified directory structure for 2025/08
# 2025-08-31 16:00:37,562 - INFO - Last processed position: 7538
# 2025-08-31 16:00:37,564 - INFO - Processing data burst file: 20250828.csv
# 2025-08-31 16:00:37,567 - INFO - File modified: 20250828.csv in data_burst
# 2025-08-31 16:00:37,568 - INFO - Parsed info: {'filename': '20250828.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250828.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 28), 'date_string': '20250828'}
# 2025-08-31 16:00:37,571 - INFO - Verified directory structure for 2025/08
# 2025-08-31 16:00:37,574 - INFO - Last processed position: 7538
# 2025-08-31 16:00:37,576 - INFO - Processing data burst file: 20250828.csv

# %%
datetime.date(2025, 8, 25)
# Out:
# datetime.date(2025, 8, 28)

# %% [markdown]
# # Implementation Testing

# %%
def test_monitor_system():
    """Test the monitoring system."""

    # Initialize the monitor
    # Set base_path to project root + "Data/Burst_Data"

    project_root = Path.cwd().parent
    print(f"Project root: {project_root}")
    base_path = project_root / "Data" / "Burst_Data"
    base_path.mkdir(parents=True, exist_ok=True)
    monitor = Ki2AlertsFileMonitor(str(base_path))

    print("=== Ki2 Alerts File Monitor Test ===")
    print(f"Base path: {monitor.base_path}")
    print()

    # Test directory creation
    current_path = monitor.get_current_year_month_path()
    print(f"Current year/month path: {current_path}")
    print()

    # Test paths for specific date
    test_date = date(2025, 8, 29)
    paths = monitor.get_paths_for_date(test_date)
    print(f"Paths for {test_date}:")
    for key, path in paths.items():
        print(f"  {key}: {path}")
    print()

    # Test filename parsing
    # test_files = [
    #     "20250829_hft1.csv",
    #     "20250829.csv", 
    #     "Burst_20250829_143022.csv"
    # ]

    # subfolder_types = ['data', 'data_burst', 'data_burst_symbols']

    # List monitored directories
    directories = monitor.list_all_monitored_directories()
    print(f"Monitored directories: {len(directories)}")
    for dir_info in directories:
        print(f"  {dir_info['year']}/{dir_info['month']}: {dir_info['path']}")
    return monitor

# Run the test
monitor = test_monitor_system()
# Out:
# 2025-08-29 17:16:28,816 - INFO - Verified directory structure for 2025/08
# 2025-08-29 17:16:28,818 - INFO - Verified directory structure for 2025/08
# Project root: c:\Users\vande\Desktop\Projects\Ki2_Alerts
# === Ki2 Alerts File Monitor Test ===
# Base path: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data
#
# Current year/month path: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08
#
# Paths for 2025-08-29:
#   data: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08\Data
#   data_burst: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08\Data_Burst
#   data_burst_symbols: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08\Data_Burst_Symbols
#   processed_data: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08\Processed_Data
#
# Monitored directories: 1
#   2025/08: c:\Users\vande\Desktop\Projects\Ki2_Alerts\Data\Burst_Data\2025\08

# %%
# Iterate through all subfolder types and scan for files in each, select only files from target date
target_date = date(2025, 8, 29)
subfolder_types = ['data', 'data_burst', 'data_burst_symbols']

for subfolder_type in subfolder_types:
    print(f"\n--- Scanning '{subfolder_type}' for {target_date} ---")
    files = monitor.scan_for_files(subfolder_type, target_date)
    filtered_files = [
        f for f in files
        if monitor.parse_filename(f, subfolder_type).get('date') == target_date
    ]
    parsed_files = [monitor.parse_filename(f, subfolder_type) for f in filtered_files]
    parsed_files = [info for info in parsed_files if info]
    for info in parsed_files:
        print(info)
# Out:
# 2025-08-29 17:17:01,177 - INFO - Verified directory structure for 2025/08
# 2025-08-29 17:17:01,182 - INFO - Verified directory structure for 2025/08
# 2025-08-29 17:17:01,184 - INFO - Verified directory structure for 2025/08
# --- Scanning 'data' for 2025-08-29 ---
# {'filename': '20250829_hft1.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250829_hft1.csv', 'subfolder_type': 'data', 'date': datetime.date(2025, 8, 29), 'file_number': 1, 'date_string': '20250829'}
# {'filename': '20250829_hft2.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250829_hft2.csv', 'subfolder_type': 'data', 'date': datetime.date(2025, 8, 29), 'file_number': 2, 'date_string': '20250829'}
# {'filename': '20250829_hft3.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data\\20250829_hft3.csv', 'subfolder_type': 'data', 'date': datetime.date(2025, 8, 29), 'file_number': 3, 'date_string': '20250829'}
#
# --- Scanning 'data_burst' for 2025-08-29 ---
# {'filename': '20250829.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst\\20250829.csv', 'subfolder_type': 'data_burst', 'date': datetime.date(2025, 8, 29), 'date_string': '20250829'}
#
# --- Scanning 'data_burst_symbols' for 2025-08-29 ---
# {'filename': 'Burst_20250829_093001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 30, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093001'}
# {'filename': 'Burst_20250829_093002.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093002.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 30, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093002'}
# {'filename': 'Burst_20250829_093003.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093003.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 30, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093003'}
# {'filename': 'Burst_20250829_093011.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093011.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 30, 11), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093011'}
# {'filename': 'Burst_20250829_093123.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093123.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 31, 23), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093123'}
# {'filename': 'Burst_20250829_093201.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093201.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 32, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093201'}
# {'filename': 'Burst_20250829_093610.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093610.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 36, 10), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093610'}
# {'filename': 'Burst_20250829_093709.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093709.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 37, 9), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093709'}
# {'filename': 'Burst_20250829_093923.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093923.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 39, 23), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093923'}
# {'filename': 'Burst_20250829_093949.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_093949.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 39, 49), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '093949'}
# {'filename': 'Burst_20250829_094552.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094552.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 45, 52), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094552'}
# {'filename': 'Burst_20250829_094600.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094600.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 46), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094600'}
# {'filename': 'Burst_20250829_094601.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094601.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 46, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094601'}
# {'filename': 'Burst_20250829_094602.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094602.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 46, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094602'}
# {'filename': 'Burst_20250829_094603.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094603.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 46, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094603'}
# {'filename': 'Burst_20250829_094626.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094626.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 46, 26), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094626'}
# {'filename': 'Burst_20250829_094655.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094655.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 46, 55), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094655'}
# {'filename': 'Burst_20250829_094701.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094701.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 47, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094701'}
# {'filename': 'Burst_20250829_094702.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094702.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 47, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094702'}
# {'filename': 'Burst_20250829_094704.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094704.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 47, 4), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094704'}
# {'filename': 'Burst_20250829_094716.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094716.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 47, 16), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094716'}
# {'filename': 'Burst_20250829_094726.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094726.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 47, 26), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094726'}
# {'filename': 'Burst_20250829_094801.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094801.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 48, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094801'}
# {'filename': 'Burst_20250829_094806.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094806.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 48, 6), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094806'}
# {'filename': 'Burst_20250829_094807.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094807.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 48, 7), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094807'}
# {'filename': 'Burst_20250829_094950.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_094950.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 49, 50), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '094950'}
# {'filename': 'Burst_20250829_095001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 50, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095001'}
# {'filename': 'Burst_20250829_095008.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095008.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 50, 8), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095008'}
# {'filename': 'Burst_20250829_095009.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095009.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 50, 9), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095009'}
# {'filename': 'Burst_20250829_095012.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095012.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 50, 12), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095012'}
# {'filename': 'Burst_20250829_095023.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095023.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 50, 23), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095023'}
# {'filename': 'Burst_20250829_095041.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095041.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 50, 41), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095041'}
# {'filename': 'Burst_20250829_095133.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095133.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 51, 33), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095133'}
# {'filename': 'Burst_20250829_095205.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095205.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 52, 5), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095205'}
# {'filename': 'Burst_20250829_095251.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095251.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 52, 51), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095251'}
# {'filename': 'Burst_20250829_095402.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095402.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 54, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095402'}
# {'filename': 'Burst_20250829_095420.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095420.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 54, 20), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095420'}
# {'filename': 'Burst_20250829_095603.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095603.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 56, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095603'}
# {'filename': 'Burst_20250829_095604.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095604.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 56, 4), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095604'}
# {'filename': 'Burst_20250829_095620.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095620.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 56, 20), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095620'}
# {'filename': 'Burst_20250829_095621.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095621.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 56, 21), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095621'}
# {'filename': 'Burst_20250829_095633.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095633.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 56, 33), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095633'}
# {'filename': 'Burst_20250829_095634.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095634.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 56, 34), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095634'}
# {'filename': 'Burst_20250829_095731.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095731.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 57, 31), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095731'}
# {'filename': 'Burst_20250829_095733.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_095733.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 9, 57, 33), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '095733'}
# {'filename': 'Burst_20250829_100001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 0, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100001'}
# {'filename': 'Burst_20250829_100002.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100002.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 0, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100002'}
# {'filename': 'Burst_20250829_100318.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100318.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 3, 18), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100318'}
# {'filename': 'Burst_20250829_100319.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100319.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 3, 19), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100319'}
# {'filename': 'Burst_20250829_100320.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100320.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 3, 20), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100320'}
# {'filename': 'Burst_20250829_100350.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100350.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 3, 50), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100350'}
# {'filename': 'Burst_20250829_100351.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100351.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 3, 51), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100351'}
# {'filename': 'Burst_20250829_100352.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100352.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 3, 52), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100352'}
# {'filename': 'Burst_20250829_100422.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100422.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 4, 22), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100422'}
# {'filename': 'Burst_20250829_100423.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100423.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 4, 23), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100423'}
# {'filename': 'Burst_20250829_100501.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100501.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100501'}
# {'filename': 'Burst_20250829_100503.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100503.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100503'}
# {'filename': 'Burst_20250829_100525.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100525.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 25), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100525'}
# {'filename': 'Burst_20250829_100526.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100526.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 26), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100526'}
# {'filename': 'Burst_20250829_100535.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100535.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 35), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100535'}
# {'filename': 'Burst_20250829_100539.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100539.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 39), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100539'}
# {'filename': 'Burst_20250829_100541.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100541.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 41), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100541'}
# {'filename': 'Burst_20250829_100542.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100542.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 42), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100542'}
# {'filename': 'Burst_20250829_100547.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100547.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 47), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100547'}
# {'filename': 'Burst_20250829_100550.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100550.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 50), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100550'}
# {'filename': 'Burst_20250829_100551.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100551.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 51), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100551'}
# {'filename': 'Burst_20250829_100552.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100552.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 52), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100552'}
# {'filename': 'Burst_20250829_100554.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100554.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 54), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100554'}
# {'filename': 'Burst_20250829_100555.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100555.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 5, 55), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100555'}
# {'filename': 'Burst_20250829_100600.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100600.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100600'}
# {'filename': 'Burst_20250829_100601.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100601.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100601'}
# {'filename': 'Burst_20250829_100602.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100602.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100602'}
# {'filename': 'Burst_20250829_100603.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100603.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100603'}
# {'filename': 'Burst_20250829_100604.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100604.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 4), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100604'}
# {'filename': 'Burst_20250829_100605.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100605.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 5), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100605'}
# {'filename': 'Burst_20250829_100607.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100607.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 7), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100607'}
# {'filename': 'Burst_20250829_100609.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100609.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 9), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100609'}
# {'filename': 'Burst_20250829_100610.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100610.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 10), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100610'}
# {'filename': 'Burst_20250829_100612.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100612.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 12), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100612'}
# {'filename': 'Burst_20250829_100613.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100613.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 13), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100613'}
# {'filename': 'Burst_20250829_100614.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100614.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 14), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100614'}
# {'filename': 'Burst_20250829_100618.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100618.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 18), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100618'}
# {'filename': 'Burst_20250829_100619.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100619.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 19), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100619'}
# {'filename': 'Burst_20250829_100626.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100626.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 26), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100626'}
# {'filename': 'Burst_20250829_100627.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100627.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 27), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100627'}
# {'filename': 'Burst_20250829_100631.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100631.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 31), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100631'}
# {'filename': 'Burst_20250829_100633.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100633.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 33), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100633'}
# {'filename': 'Burst_20250829_100637.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100637.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 37), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100637'}
# {'filename': 'Burst_20250829_100638.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100638.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 38), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100638'}
# {'filename': 'Burst_20250829_100640.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100640.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 40), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100640'}
# {'filename': 'Burst_20250829_100643.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100643.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 43), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100643'}
# {'filename': 'Burst_20250829_100644.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100644.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 44), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100644'}
# {'filename': 'Burst_20250829_100645.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100645.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 45), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100645'}
# {'filename': 'Burst_20250829_100648.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100648.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 48), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100648'}
# {'filename': 'Burst_20250829_100650.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100650.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 50), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100650'}
# {'filename': 'Burst_20250829_100652.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100652.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 52), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100652'}
# {'filename': 'Burst_20250829_100653.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100653.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 53), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100653'}
# {'filename': 'Burst_20250829_100658.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100658.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 58), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100658'}
# {'filename': 'Burst_20250829_100659.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100659.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 6, 59), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100659'}
# {'filename': 'Burst_20250829_100702.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100702.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 7, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100702'}
# {'filename': 'Burst_20250829_100711.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100711.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 7, 11), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100711'}
# {'filename': 'Burst_20250829_100713.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100713.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 7, 13), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100713'}
# {'filename': 'Burst_20250829_100749.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100749.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 7, 49), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100749'}
# {'filename': 'Burst_20250829_100801.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100801.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 8, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100801'}
# {'filename': 'Burst_20250829_100803.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100803.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 8, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100803'}
# {'filename': 'Burst_20250829_100836.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100836.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 8, 36), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100836'}
# {'filename': 'Burst_20250829_100837.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100837.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 8, 37), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100837'}
# {'filename': 'Burst_20250829_100901.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100901.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 9, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100901'}
# {'filename': 'Burst_20250829_100906.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100906.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 9, 6), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100906'}
# {'filename': 'Burst_20250829_100910.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100910.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 9, 10), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100910'}
# {'filename': 'Burst_20250829_100919.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100919.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 9, 19), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100919'}
# {'filename': 'Burst_20250829_100930.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100930.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 9, 30), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100930'}
# {'filename': 'Burst_20250829_100931.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100931.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 9, 31), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100931'}
# {'filename': 'Burst_20250829_100948.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_100948.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 9, 48), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '100948'}
# {'filename': 'Burst_20250829_101017.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101017.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 10, 17), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101017'}
# {'filename': 'Burst_20250829_101046.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101046.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 10, 46), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101046'}
# {'filename': 'Burst_20250829_101056.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101056.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 10, 56), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101056'}
# {'filename': 'Burst_20250829_101102.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101102.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 11, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101102'}
# {'filename': 'Burst_20250829_101159.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101159.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 11, 59), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101159'}
# {'filename': 'Burst_20250829_101201.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101201.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101201'}
# {'filename': 'Burst_20250829_101207.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101207.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 7), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101207'}
# {'filename': 'Burst_20250829_101218.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101218.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 18), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101218'}
# {'filename': 'Burst_20250829_101219.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101219.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 19), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101219'}
# {'filename': 'Burst_20250829_101231.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101231.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 31), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101231'}
# {'filename': 'Burst_20250829_101232.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101232.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 32), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101232'}
# {'filename': 'Burst_20250829_101239.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101239.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 39), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101239'}
# {'filename': 'Burst_20250829_101258.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101258.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 12, 58), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101258'}
# {'filename': 'Burst_20250829_101301.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_101301.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 10, 13, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '101301'}
# ...
# {'filename': 'Burst_20250829_142055.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_142055.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 14, 20, 55), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '142055'}
# {'filename': 'Burst_20250829_155001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 50, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155001'}
# {'filename': 'Burst_20250829_155002.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155002.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 50, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155002'}
# {'filename': 'Burst_20250829_155003.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155003.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 50, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155003'}
# {'filename': 'Burst_20250829_155004.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155004.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 50, 4), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155004'}
# {'filename': 'Burst_20250829_155025.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155025.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 50, 25), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155025'}
# {'filename': 'Burst_20250829_155102.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155102.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 51, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155102'}
# {'filename': 'Burst_20250829_155205.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155205.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 52, 5), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155205'}
# {'filename': 'Burst_20250829_155228.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155228.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 52, 28), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155228'}
# {'filename': 'Burst_20250829_155401.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155401.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 54, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155401'}
# {'filename': 'Burst_20250829_155411.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155411.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 54, 11), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155411'}
# {'filename': 'Burst_20250829_155441.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155441.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 54, 41), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155441'}
# {'filename': 'Burst_20250829_155442.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155442.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 54, 42), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155442'}
# {'filename': 'Burst_20250829_155451.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155451.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 54, 51), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155451'}
# {'filename': 'Burst_20250829_155501.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155501.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 55, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155501'}
# {'filename': 'Burst_20250829_155502.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155502.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 55, 2), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155502'}
# {'filename': 'Burst_20250829_155503.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155503.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 55, 3), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155503'}
# {'filename': 'Burst_20250829_155505.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155505.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 55, 5), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155505'}
# {'filename': 'Burst_20250829_155719.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155719.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 57, 19), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155719'}
# {'filename': 'Burst_20250829_155810.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155810.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 58, 10), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155810'}
# {'filename': 'Burst_20250829_155831.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155831.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 58, 31), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155831'}
# {'filename': 'Burst_20250829_155832.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155832.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 58, 32), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155832'}
# {'filename': 'Burst_20250829_155901.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155901.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155901'}
# {'filename': 'Burst_20250829_155922.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155922.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 22), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155922'}
# {'filename': 'Burst_20250829_155923.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155923.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 23), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155923'}
# {'filename': 'Burst_20250829_155924.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155924.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 24), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155924'}
# {'filename': 'Burst_20250829_155931.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155931.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 31), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155931'}
# {'filename': 'Burst_20250829_155941.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155941.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 41), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155941'}
# {'filename': 'Burst_20250829_155942.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155942.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 42), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155942'}
# {'filename': 'Burst_20250829_155946.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155946.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 46), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155946'}
# {'filename': 'Burst_20250829_155947.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155947.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 47), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155947'}
# {'filename': 'Burst_20250829_155948.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155948.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 48), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155948'}
# {'filename': 'Burst_20250829_155951.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155951.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 51), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155951'}
# {'filename': 'Burst_20250829_155952.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155952.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 52), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155952'}
# {'filename': 'Burst_20250829_155953.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155953.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 53), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155953'}
# {'filename': 'Burst_20250829_155954.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155954.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 54), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155954'}
# {'filename': 'Burst_20250829_155955.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155955.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 55), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155955'}
# {'filename': 'Burst_20250829_155956.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155956.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 56), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155956'}
# {'filename': 'Burst_20250829_155957.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155957.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 57), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155957'}
# {'filename': 'Burst_20250829_155958.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155958.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 58), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155958'}
# {'filename': 'Burst_20250829_155959.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_155959.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 15, 59, 59), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '155959'}
# {'filename': 'Burst_20250829_160000.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_160000.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 16, 0), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '160000'}
# {'filename': 'Burst_20250829_160001.csv', 'full_path': 'c:\\Users\\vande\\Desktop\\Projects\\Ki2_Alerts\\Data\\Burst_Data\\2025\\08\\Data_Burst_Symbols\\Burst_20250829_160001.csv', 'subfolder_type': 'data_burst_symbols', 'datetime': datetime.datetime(2025, 8, 29, 16, 0, 1), 'date': datetime.date(2025, 8, 29), 'date_string': '20250829', 'time_string': '160001'}
